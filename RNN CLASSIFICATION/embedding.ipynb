# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=[
    'the galss of milk',
    'the glass of juice',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]

# %%
sent
# Out:
# ['the galss of milk',
#  'the glass of juice',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
voc_size=10000

# %%
one_hot_representation=[one_hot(words,voc_size) for words in sent]

# %%
one_hot_representation
# Out:
# [[1103, 4023, 7046, 7262],
#  [1103, 5639, 7046, 4931],
#  [5453, 2348, 603, 4241, 2325],
#  [5453, 2348, 603, 4241, 7027],
#  [9597, 1103, 5373, 7046, 3885],
#  [4786, 3328, 8000, 4241]]

# %%
## word embedding reprsentation layers

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8 # make every sent length to 8th so that we cantrain model easily
embedded_docs=pad_sequences(one_hot_representation,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 1103 4023 7046 7262]
#  [   0    0    0    0 1103 5639 7046 4931]
#  [   0    0    0 5453 2348  603 4241 2325]
#  [   0    0    0 5453 2348  603 4241 7027]
#  [   0    0    0 9597 1103 5373 7046 3885]
#  [   0    0    0    0 4786 3328 8000 4241]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From e:\Deep Learning\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING:tensorflow:From e:\Deep Learning\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 410ms/step
# array([[[ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [-0.03865929,  0.00101047,  0.02610977,  0.02018711,
#           0.02829827, -0.02156898, -0.04528449, -0.01971056,
#          -0.01295422, -0.04087235],
#         [-0.00943372, -0.04359851,  0.02629979,  0.00578933,
#           0.00128517, -0.02631502, -0.027554  , -0.00940776,
#          -0.01630551,  0.03745176],
#         [-0.02961918, -0.00641654,  0.03013981, -0.04106898,
#          -0.00182911, -0.01193376, -0.04287697,  0.01625106,
#          -0.0419162 ,  0.02182484],
#         [ 0.00691186, -0.03866824, -0.04746603,  0.00166357,
#          -0.04874533, -0.02568137, -0.00136763, -0.00438537,
#           0.03889308,  0.01945071]],
#
#        [[ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [-0.03865929,  0.00101047,  0.02610977,  0.02018711,
#           0.02829827, -0.02156898, -0.04528449, -0.01971056,
#          -0.01295422, -0.04087235],
#         [-0.04804796,  0.0250577 , -0.01648734,  0.02402375,
#          -0.02629529, -0.00486724, -0.0362261 ,  0.02387318,
#           0.00068044, -0.03070843],
#         [-0.02961918, -0.00641654,  0.03013981, -0.04106898,
#          -0.00182911, -0.01193376, -0.04287697,  0.01625106,
#          -0.0419162 ,  0.02182484],
#         [-0.01144695,  0.01832053,  0.0045343 , -0.00067297,
#           0.01807057,  0.03523983,  0.02006862, -0.02829731,
#           0.04138902,  0.00095543]],
#
#        [[ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [-0.03008176,  0.04097312, -0.04735726, -0.00010655,
#          -0.0204584 ,  0.04462628, -0.00504739, -0.00489876,
#           0.00294501,  0.02508087],
#         [ 0.03997375,  0.01215696,  0.03654934,  0.00369139,
#          -0.01387341,  0.02305381,  0.03116002, -0.01912197,
#           0.03966404,  0.02938649],
#         [-0.03763251, -0.02292842,  0.01587503, -0.00980679,
#          -0.02748821, -0.04273222, -0.04681071, -0.04702405,
#           0.030965  , -0.03267347],
#         [-0.02787114,  0.00130262,  0.01846144,  0.01888623,
#          -0.0020956 ,  0.04396245,  0.02272503, -0.00147154,
#          -0.04264959, -0.02393644],
#         [ 0.03467708,  0.01348677,  0.01861874, -0.04641458,
#           0.0480732 , -0.00301052,  0.04246818,  0.0382641 ,
#           0.03164569,  0.01804055]],
#
#        [[ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [-0.03008176,  0.04097312, -0.04735726, -0.00010655,
#          -0.0204584 ,  0.04462628, -0.00504739, -0.00489876,
#           0.00294501,  0.02508087],
#         [ 0.03997375,  0.01215696,  0.03654934,  0.00369139,
#          -0.01387341,  0.02305381,  0.03116002, -0.01912197,
#           0.03966404,  0.02938649],
#         [-0.03763251, -0.02292842,  0.01587503, -0.00980679,
#          -0.02748821, -0.04273222, -0.04681071, -0.04702405,
#           0.030965  , -0.03267347],
#         [-0.02787114,  0.00130262,  0.01846144,  0.01888623,
#          -0.0020956 ,  0.04396245,  0.02272503, -0.00147154,
#          -0.04264959, -0.02393644],
#         [ 0.02149402,  0.01401371, -0.0133948 ,  0.00773722,
#          -0.02134303,  0.04992637,  0.04864296,  0.04881778,
#          -0.00467124,  0.0483018 ]],
#
#        [[ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.03046527,  0.00644026, -0.01986769, -0.04608936,
#           0.02541215, -0.044386  ,  0.00204499,  0.00136073,
#           0.01489038, -0.02563027],
#         [-0.03865929,  0.00101047,  0.02610977,  0.02018711,
#           0.02829827, -0.02156898, -0.04528449, -0.01971056,
#          -0.01295422, -0.04087235],
#         [ 0.02805067, -0.0304601 ,  0.04234466, -0.00455523,
#          -0.03013772,  0.00614568,  0.01144332,  0.00406047,
#          -0.02729203,  0.01315861],
#         [-0.02961918, -0.00641654,  0.03013981, -0.04106898,
#          -0.00182911, -0.01193376, -0.04287697,  0.01625106,
#          -0.0419162 ,  0.02182484],
#         [-0.01106241, -0.00805291,  0.04856993, -0.01626172,
#          -0.04122368, -0.00826435, -0.0317845 ,  0.00608926,
#           0.02839367, -0.02078861]],
#
#        [[ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,
#           0.04953319,  0.01888433, -0.00573678,  0.0139866 ,
#          -0.03074881,  0.0228608 ],
#         [ 0.0102721 ,  0.0124187 ,  0.00934809, -0.0178095 ,
#           0.03536059,  0.00673109, -0.03939871, -0.01950116,
#          -0.04581329, -0.02866112],
#         [ 0.02156157,  0.03415432, -0.04234394,  0.03702949,
#          -0.00649429, -0.03960446, -0.01863737,  0.017798  ,
#          -0.02754235,  0.02609844],
#         [-0.04934376,  0.03407623, -0.00898323,  0.01134404,
#           0.02388812, -0.02730241,  0.0178339 ,  0.0320367 ,
#           0.03105595, -0.03078182],
#         [-0.02787114,  0.00130262,  0.01846144,  0.01888623,
#          -0.0020956 ,  0.04396245,  0.02272503, -0.00147154,
#          -0.04264959, -0.02393644]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 1103, 4023, 7046, 7262])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 36ms/step
# array([[ 0.01115083, -0.00453988, -0.02562132,  0.00835129,  0.04953319,
#          0.01888433, -0.00573678,  0.0139866 , -0.03074881,  0.0228608 ],
#        [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,  0.04953319,
#          0.01888433, -0.00573678,  0.0139866 , -0.03074881,  0.0228608 ],
#        [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,  0.04953319,
#          0.01888433, -0.00573678,  0.0139866 , -0.03074881,  0.0228608 ],
#        [ 0.01115083, -0.00453988, -0.02562132,  0.00835129,  0.04953319,
#          0.01888433, -0.00573678,  0.0139866 , -0.03074881,  0.0228608 ],
#        [-0.03865929,  0.00101047,  0.02610977,  0.02018711,  0.02829827,
#         -0.02156898, -0.04528449, -0.01971056, -0.01295422, -0.04087235],
#        [-0.00943372, -0.04359851,  0.02629979,  0.00578933,  0.00128517,
#         -0.02631502, -0.027554  , -0.00940776, -0.01630551,  0.03745176],
#        [-0.02961918, -0.00641654,  0.03013981, -0.04106898, -0.00182911,
#         -0.01193376, -0.04287697,  0.01625106, -0.0419162 ,  0.02182484],
#        [ 0.00691186, -0.03866824, -0.04746603,  0.00166357, -0.04874533,
#         -0.02568137, -0.00136763, -0.00438537,  0.03889308,  0.01945071]],
#       dtype=float32)
